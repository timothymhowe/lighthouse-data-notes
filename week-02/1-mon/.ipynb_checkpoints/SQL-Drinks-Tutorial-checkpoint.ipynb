# %% [markdown]
# # SQL Tutorial
#
# In this tutorial, we will be using [SQLite](https://www.sqlite.org/about.html) to practice SQL. There are several ways to query a SQLite database with python such as sqlite3 and SQLAlchemy--here we will use **[ipython-sql](https://github.com/catherinedevlin/ipython-sql)**. You can install it using `pip install ipython-sql` or `conda install ipython-sql`. The `ipython-sql` library is loaded using the `%load_ext` just like other iPython extension syntax.

# %%
# import sys
# !conda install -c conda-forge --yes --prefix {sys.prefix} ipython-sql

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# ---
#
# ## Query Database Information
#
# First, let's connect to a SQL database located in the `data` directory. Then we will explore the database by examing the tables within the database.

# %%
# Out:
# 'Connected: @data/drinks.db3'

# %% [markdown]
# ### List  tables in a database
#
# Table and index names can be list by doing a **SELECT** on a special table named "***SQLITE_MASTER***". Every SQLite database has an SQLITE_MASTER table that defines the schema for the database. For tables, the ***type*** field will always be '***table***' and the name field will be the name of the table. So to get a list of all tables in the database, use the following SELECT command:
#
# See more at https://www.sqlite.org/faq.html#q7.

# %%
# %sql SELECT table_name FROM sqlite_master WHERE type='table'
# Out:
#  * sqlite://
#    sqlite:///data/drinks.db3
# (sqlite3.OperationalError) no such column: table_name
# [SQL: SELECT table_name FROM sqlite_master WHERE type='table']
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %% [markdown]
# Note: We can also write multi-line SQL code as follows:

# %%
# %%sql sqlite://
# SELECT name
# FROM sqlite_master
# WHERE type='table'
# Out:
# Done.
# []

# %% [markdown]
# ### Explore the tables
#
# We can use a simple `SELECT *` to explore our tables and view their columns. We can also add a `LIMIT` command to only view the first few rows.

# %%
# %sql select * from drinks
# %sql SELECT * from menu_items
#%sql select * from orders
#%sql select * from orders LIMIT 10
# Out:
#  * sqlite://
#    sqlite:///data/drinks.db3
# (sqlite3.OperationalError) no such table: menu_items
# [SQL: SELECT * from menu_items]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %% [markdown]
# > Notice SQL is NOT case-sensitive. Typically SQL commands are written in ALL CAPS for clarity.
#
# To summarize, we have the following tables and columns:
#
# <table style="border: 5px; width: 100%">
#  <tr>
#     <td><b style="font-size:30px">menu_items</b></td>
#     <td><b style="font-size:30px">orders</b></td>
#     <td><b style="font-size:30px">drinks</b></td>
#  </tr>
#  <tr>
#     <td style="font-size:20px"><b>drink_id</b>: string</td>
#     <td style="font-size:20px"><b>drink_id</b>: string</td>
#     <td style="font-size:20px"><b>drink_id</b>: string</td>
#  </tr>
#  <tr>
#     <td style="font-size:20px"><b>bar</b>: string</td>
#     <td style="font-size:20px"><b>bar</b>: string</td>
#     <td style="font-size:20px"><b>type</b>: string</td>
#  </tr>
#  <tr>
#     <td style="font-size:20px"><b>price</b>: real</td>
#     <td style="font-size:20px"><b>person</b>: string</td>
#     <td style="font-size:20px"></td>
#  </tr>
#  <tr>
#     <td style="font-size:20px"></td>
#     <td style="font-size:20px"><b>date</b>: string</td>
#     <td style="font-size:20px"></td>
#  </tr>
#  <tr>
#     <td style="font-size:20px"></td>
#     <td style="font-size:20px"><b>quantity</b>: integer</td>
#     <td style="font-size:20px"></td>
#  </tr>
# </table>

# %% [markdown]
# Which table is the fact table, and which are dimension tables?

# %% [markdown]
# ---
# ## Some SQL references before we get started
# ![](images/sql-cheat-sheet.png)
#
# ## Order of operations *VERY USEFUL!!*
# ![](images/order_of_operations.png)

# %% [markdown]
# # Time to start writing some queries!

# %% [markdown]
# ---
# ## Problem 1
# Get the bar name and average price of drinks at each bar.
# <table style="border: 5px; width: 100%">
#  <tr>
#     <td><b style="font-size:30px">menu_items</b></td>
#     <td><b style="font-size:30px">orders</b></td>
#     <td><b style="font-size:30px">drinks</b></td>
#  </tr>
#  <tr>
#     <td style="font-size:20px"><b>drink_id</b>: string</td>
#     <td style="font-size:20px"><b>drink_id</b>: string</td>
#     <td style="font-size:20px"><b>drink_id</b>: string</td>
#  </tr>
#  <tr>
#     <td style="font-size:20px"><b>bar</b>: string</td>
#     <td style="font-size:20px"><b>bar</b>: string</td>
#     <td style="font-size:20px"><b>type</b>: string</td>
#  </tr>
#  <tr>
#     <td style="font-size:20px"><b>price</b>: real</td>
#     <td style="font-size:20px"><b>person</b>: string</td>
#     <td style="font-size:20px"></td>
#  </tr>
#  <tr>
#     <td style="font-size:20px"></td>
#     <td style="font-size:20px"><b>date</b>: string</td>
#     <td style="font-size:20px"></td>
#  </tr>
#  <tr>
#     <td style="font-size:20px"></td>
#     <td style="font-size:20px"><b>quantity</b>: integer</td>
#     <td style="font-size:20px"></td>
#  </tr>
# </table>

# %%
# %sql sqlite:///data/drinks.db3
# %sql SELECT bar, AVG(price) FROM menu_items GROUP BY bar
# Out:
#    sqlite://
#  * sqlite:///data/drinks.db3
# Done.
# [('bar 1', 83.67852094673019),
#  ('bar 10', 60.572635788204416),
#  ('bar 11', 31.562558906114038),
#  ('bar 12', 152.0710318342317),
#  ('bar 13', 150.56043863608502),
#  ('bar 14', 93.4388559625484),
#  ('bar 15', 90.99379045958631),
#  ('bar 16', 121.36436782585224),
#  ('bar 17', 107.32970053202007),
#  ('bar 18', 105.21477991195086),
#  ('bar 19', 18.22443392399388),
#  ('bar 2', 60.25870316987857),
#  ('bar 20', 86.51315756270196),
#  ('bar 3', 129.8095159989316),
#  ('bar 4', 49.2509780030814),
#  ('bar 5', 100.60385745142896),
#  ('bar 6', 27.682567102989804),
#  ('bar 7', 61.56748556054663),
#  ('bar 8', 67.91904428955168),
#  ('bar 9', 52.38170580135193)]

# %% [markdown]
# ---
# ## Problem 2
# Get the bars with the top 5 average prices.
# <table style="border: 5px; width: 100%">
#  <tr>
#     <td><b style="font-size:30px">menu_items</b></td>
#     <td><b style="font-size:30px">orders</b></td>
#     <td><b style="font-size:30px">drinks</b></td>
#  </tr>
#  <tr>
#     <td style="font-size:20px"><b>drink_id</b>: string</td>
#     <td style="font-size:20px"><b>drink_id</b>: string</td>
#     <td style="font-size:20px"><b>drink_id</b>: string</td>
#  </tr>
#  <tr>
#     <td style="font-size:20px"><b>bar</b>: string</td>
#     <td style="font-size:20px"><b>bar</b>: string</td>
#     <td style="font-size:20px"><b>type</b>: string</td>
#  </tr>
#  <tr>
#     <td style="font-size:20px"><b>price</b>: real</td>
#     <td style="font-size:20px"><b>person</b>: string</td>
#     <td style="font-size:20px"></td>
#  </tr>
#  <tr>
#     <td style="font-size:20px"></td>
#     <td style="font-size:20px"><b>date</b>: string</td>
#     <td style="font-size:20px"></td>
#  </tr>
#  <tr>
#     <td style="font-size:20px"></td>
#     <td style="font-size:20px"><b>quantity</b>: integer</td>
#     <td style="font-size:20px"></td>
#  </tr>
# </table>

# %%
# %sql sqlite:///data/drinks.db3
# %sql SELECT bar, AVG(price) AS avg_price FROM menu_items GROUP BY bar ORDER BY avg_price DESC LIMIT 5;
# Out:
#    sqlite://
#  * sqlite:///data/drinks.db3
# Done.
# [('bar 12', 152.0710318342317),
#  ('bar 13', 150.56043863608502),
#  ('bar 3', 129.8095159989316),
#  ('bar 16', 121.36436782585224),
#  ('bar 17', 107.32970053202007)]

# %% [markdown]
# ---
# ## Problem 3
# Get the bar with the cheapest drink, along with the drink type and price.
# <table style="border: 5px; width: 100%">
#  <tr>
#     <td><b style="font-size:30px">menu_items</b></td>
#     <td><b style="font-size:30px">orders</b></td>
#     <td><b style="font-size:30px">drinks</b></td>
#  </tr>
#  <tr>
#     <td style="font-size:20px"><b>drink_id</b>: string</td>
#     <td style="font-size:20px"><b>drink_id</b>: string</td>
#     <td style="font-size:20px"><b>drink_id</b>: string</td>
#  </tr>
#  <tr>
#     <td style="font-size:20px"><b>bar</b>: string</td>
#     <td style="font-size:20px"><b>bar</b>: string</td>
#     <td style="font-size:20px"><b>type</b>: string</td>
#  </tr>
#  <tr>
#     <td style="font-size:20px"><b>price</b>: real</td>
#     <td style="font-size:20px"><b>person</b>: string</td>
#     <td style="font-size:20px"></td>
#  </tr>
#  <tr>
#     <td style="font-size:20px"></td>
#     <td style="font-size:20px"><b>date</b>: string</td>
#     <td style="font-size:20px"></td>
#  </tr>
#  <tr>
#     <td style="font-size:20px"></td>
#     <td style="font-size:20px"><b>quantity</b>: integer</td>
#     <td style="font-size:20px"></td>
#  </tr>
# </table>

# %%
# %sql SELECT menu_items.bar, drinks.type, menu_items.price FROM menu_items  INNER JOIN drinks ON menu_items.drink_id=drinks.drink_id ORDER BY price ASC LIMIT 1;
# Out:
#    sqlite://
#  * sqlite:///data/drinks.db3
# Done.
# [('bar 18', 'soda', 3.477885484928265)]

# %% [markdown]
# ---
# ## Problem 4
# Get the number of beers sold by each bar in descending order (number of beers sold, not the number of beers on their menu).
# <table style="border: 5px; width: 100%">
#  <tr>
#     <td><b style="font-size:30px">menu_items</b></td>
#     <td><b style="font-size:30px">orders</b></td>
#     <td><b style="font-size:30px">drinks</b></td>
#  </tr>
#  <tr>
#     <td style="font-size:20px"><b>drink_id</b>: string</td>
#     <td style="font-size:20px"><b>drink_id</b>: string</td>
#     <td style="font-size:20px"><b>drink_id</b>: string</td>
#  </tr>
#  <tr>
#     <td style="font-size:20px"><b>bar</b>: string</td>
#     <td style="font-size:20px"><b>bar</b>: string</td>
#     <td style="font-size:20px"><b>type</b>: string</td>
#  </tr>
#  <tr>
#     <td style="font-size:20px"><b>price</b>: real</td>
#     <td style="font-size:20px"><b>person</b>: string</td>
#     <td style="font-size:20px"></td>
#  </tr>
#  <tr>
#     <td style="font-size:20px"></td>
#     <td style="font-size:20px"><b>date</b>: string</td>
#     <td style="font-size:20px"></td>
#  </tr>
#  <tr>
#     <td style="font-size:20px"></td>
#     <td style="font-size:20px"><b>quantity</b>: integer</td>
#     <td style="font-size:20px"></td>
#  </tr>
# </table>

# %%
# %sql sqlite:///data/drinks.db3
# %%sql sqlite://
SELECT orders.bar, SUM(orders.quantity) as beers_sold
FROM orders 
JOIN drinks ON drinks.drink_id = orders.drink_id 
WHERE drinks.type = 'beer' 
GROUP BY bar ORDER BY beers_sold DESC
# %sql SELECT orders.bar, SUM(orders.quantity) AS beers_sold FROM orders JOIN drinks ON drinks.drink_id = orders.drink_id WHERE drinks.type = 'beer' GROUP BY bar ORDER BY beers_sold DESC
# Out:
#   File "<ipython-input-105-92647df9762b>", line 3
#     SELECT orders.bar, SUM(orders.quantity) as beers_sold
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ---
# ## Problem 5
# For each person, find the bars they visit, and the type(s) and price(s) of the drink(s) they drink during those visits.
# <table style="border: 5px; width: 100%">
#  <tr>
#     <td><b style="font-size:30px">menu_items</b></td>
#     <td><b style="font-size:30px">orders</b></td>
#     <td><b style="font-size:30px">drinks</b></td>
#  </tr>
#  <tr>
#     <td style="font-size:20px"><b>drink_id</b>: string</td>
#     <td style="font-size:20px"><b>drink_id</b>: string</td>
#     <td style="font-size:20px"><b>drink_id</b>: string</td>
#  </tr>
#  <tr>
#     <td style="font-size:20px"><b>bar</b>: string</td>
#     <td style="font-size:20px"><b>bar</b>: string</td>
#     <td style="font-size:20px"><b>type</b>: string</td>
#  </tr>
#  <tr>
#     <td style="font-size:20px"><b>price</b>: real</td>
#     <td style="font-size:20px"><b>person</b>: string</td>
#     <td style="font-size:20px"></td>
#  </tr>
#  <tr>
#     <td style="font-size:20px"></td>
#     <td style="font-size:20px"><b>date</b>: string</td>
#     <td style="font-size:20px"></td>
#  </tr>
#  <tr>
#     <td style="font-size:20px"></td>
#     <td style="font-size:20px"><b>quantity</b>: integer</td>
#     <td style="font-size:20px"></td>
#  </tr>
# </table>

# %%
# %sql sqlite:///data/drinks.db3
# %sql SELECT o.person, o.bar, d.type, m.price FROM orders AS o JOIN menu_items AS m ON (o.drink_id = m.drink_id AND o.bar = m.bar) JOIN drinks AS d ON o.drink_id = d.drink_id GROUP BY o.person, o.bar, d.type, m.price, d.drink_id
# Out:
#    sqlite://
#  * sqlite:///data/drinks.db3
#    sqlite:///data/drinks.db3;
# Done.
# [('person 1', 'bar 14', 'wine', 6.28380866907537),
#  ('person 1', 'bar 14', 'wine', 304.05416238261387),
#  ('person 1', 'bar 18', 'soda', 3.477885484928265),
#  ('person 1', 'bar 19', 'cocktail', 11.775652277283372),
#  ('person 1', 'bar 19', 'rum', 18.195812245830894),
#  ('person 1', 'bar 19', 'whisky', 34.50718138250522),
#  ('person 1', 'bar 9', 'cocktail', 26.487211599014696),
#  ('person 1', 'bar 9', 'vodka', 99.06146339606494),
#  ('person 10', 'bar 1', 'cocktail', 17.112810402177274),
#  ('person 10', 'bar 1', 'wine', 313.7675603996031),
#  ('person 10', 'bar 12', 'whisky', 50.32640918623656),
#  ('person 10', 'bar 12', 'wine', 443.17386074643576),
#  ('person 10', 'bar 17', 'beer', 4.947325653862208),
#  ('person 10', 'bar 17', 'wine', 302.8571365196258),
#  ('person 10', 'bar 19', 'cocktail', 11.775652277283372),
#  ('person 10', 'bar 19', 'rum', 18.195812245830894),
#  ('person 10', 'bar 19', 'whisky', 34.50718138250522),
#  ('person 10', 'bar 3', 'beer', 4.634161106310785),
#  ('person 10', 'bar 3', 'whisky', 52.187310544541106),
#  ('person 10', 'bar 4', 'vodka', 34.62181418668479),
#  ('person 10', 'bar 4', 'whisky', 65.86470233043656),
#  ('person 10', 'bar 5', 'soda', 7.172601338941604),
#  ('person 10', 'bar 5', 'wine', 468.4320961767807),
#  ('person 10', 'bar 7', 'soda', 7.467219435609877),
#  ('person 10', 'bar 7', 'vodka', 47.559167791623615),
#  ('person 10', 'bar 7', 'whisky', 91.36447654338554),
#  ('person 100', 'bar 12', 'cocktail', 26.84480233117938),
#  ('person 100', 'bar 12', 'whisky', 50.32640918623656),
#  ('person 100', 'bar 12', 'wine', 443.17386074643576),
#  ('person 100', 'bar 15', 'cocktail', 25.87160057388246),
#  ('person 100', 'bar 15', 'wine', 144.248119993601),
#  ('person 100', 'bar 2', 'beer', 7.54580516833812),
#  ('person 100', 'bar 2', 'cocktail', 18.34535005968064),
#  ('person 100', 'bar 2', 'rum', 6.4497588458471),
#  ('person 11', 'bar 11', 'cocktail', 22.64080404303968),
#  ('person 11', 'bar 11', 'whisky', 46.720566569129),
#  ('person 11', 'bar 14', 'vodka', 57.02846114523709),
#  ('person 11', 'bar 14', 'wine', 6.28380866907537),
#  ('person 11', 'bar 14', 'wine', 304.05416238261387),
#  ('person 11', 'bar 19', 'cocktail', 11.775652277283372),
#  ('person 11', 'bar 19', 'rum', 18.195812245830894),
#  ('person 11', 'bar 7', 'vodka', 47.559167791623615),
#  ('person 11', 'bar 7', 'whisky', 91.36447654338554),
#  ('person 12', 'bar 13', 'wine', 289.89556255424395),
#  ('person 12', 'bar 13', 'wine', 411.3109796284698),
#  ('person 12', 'bar 14', 'vodka', 57.02846114523709),
#  ('person 12', 'bar 14', 'wine', 6.28380866907537),
#  ('person 12', 'bar 15', 'whisky', 53.23563067126088),
#  ('person 12', 'bar 15', 'wine', 144.248119993601),
#  ('person 12', 'bar 16', 'soda', 8.259685171069577),
#  ('person 12', 'bar 17', 'beer', 4.947325653862208),
#  ('person 12', 'bar 17', 'whisky', 23.555515306070447),
#  ('person 12', 'bar 17', 'wine', 302.8571365196258),
#  ('person 12', 'bar 4', 'vodka', 34.62181418668479),
#  ('person 12', 'bar 4', 'vodka', 93.54708173545077),
#  ('person 12', 'bar 4', 'whisky', 65.86470233043656),
#  ('person 12', 'bar 5', 'beer', 8.457143946550786),
#  ('person 12', 'bar 5', 'wine', 468.4320961767807),
#  ('person 12', 'bar 6', 'cocktail', 12.44799837935716),
#  ('person 12', 'bar 6', 'rum', 15.327792656607926),
#  ('person 12', 'bar 6', 'whisky', 55.271910273004316),
#  ('person 13', 'bar 11', 'beer', 6.242309574503452),
#  ('person 13', 'bar 11', 'cocktail', 22.64080404303968),
#  ('person 13', 'bar 12', 'cocktail', 26.84480233117938),
#  ('person 13', 'bar 13', 'wine', 289.89556255424395),
#  ('person 13', 'bar 13', 'wine', 411.3109796284698),
#  ('person 13', 'bar 14', 'vodka', 57.02846114523709),
#  ('person 13', 'bar 14', 'wine', 6.28380866907537),
#  ('person 13', 'bar 14', 'wine', 304.05416238261387),
#  ('person 13', 'bar 16', 'cocktail', 27.076269071549177),
#  ('person 13', 'bar 16', 'soda', 8.259685171069577),
#  ('person 13', 'bar 18', 'soda', 3.477885484928265),
#  ('person 13', 'bar 18', 'vodka', 79.2083988361992),
#  ('person 13', 'bar 18', 'wine', 232.95805541472507),
#  ('person 13', 'bar 2', 'beer', 7.54580516833812),
#  ('person 13', 'bar 20', 'beer', 6.543673591222614),
#  ('person 13', 'bar 20', 'beer', 7.961273210588843),
#  ('person 13', 'bar 20', 'rum', 9.153013579780236),
#  ('person 13', 'bar 3', 'beer', 4.634161106310785),
#  ('person 13', 'bar 3', 'soda', 7.087707950500771),
#  ('person 13', 'bar 3', 'whisky', 52.187310544541106),
#  ('person 13', 'bar 4', 'vodka', 34.62181418668479),
#  ('person 13', 'bar 4', 'vodka', 93.54708173545077),
#  ('person 13', 'bar 4', 'whisky', 65.86470233043656),
#  ('person 13', 'bar 5', 'beer', 8.457143946550786),
#  ('person 13', 'bar 5', 'soda', 7.172601338941604),
#  ('person 13', 'bar 5', 'wine', 468.4320961767807),
#  ('person 13', 'bar 9', 'cocktail', 26.487211599014696),
#  ('person 14', 'bar 13', 'wine', 289.89556255424395),
#  ('person 14', 'bar 20', 'beer', 6.543673591222614),
#  ('person 14', 'bar 20', 'beer', 7.961273210588843),
#  ('person 14', 'bar 20', 'rum', 9.153013579780236),
#  ('person 14', 'bar 4', 'vodka', 34.62181418668479),
#  ('person 14', 'bar 4', 'vodka', 93.54708173545077),
#  ('person 14', 'bar 4', 'whisky', 65.86470233043656),
#  ('person 15', 'bar 1', 'whisky', 60.820202879840515),
#  ('person 15', 'bar 1', 'wine', 313.7675603996031),
#  ('person 15', 'bar 19', 'rum', 18.195812245830894),
#  ('person 15', 'bar 19', 'whisky', 34.50718138250522),
#  ('person 15', 'bar 20', 'beer', 6.543673591222614),
#  ('person 15', 'bar 20', 'beer', 7.961273210588843),
#  ('person 15', 'bar 20', 'rum', 9.153013579780236),
#  ('person 15', 'bar 3', 'beer', 4.634161106310785),
#  ('person 15', 'bar 3', 'soda', 7.087707950500771),
#  ('person 15', 'bar 5', 'beer', 8.457143946550786),
#  ('person 15', 'bar 5', 'soda', 7.172601338941604),
#  ('person 15', 'bar 5', 'wine', 468.4320961767807),
#  ('person 15', 'bar 6', 'cocktail', 12.44799837935716),
#  ('person 15', 'bar 6', 'rum', 15.327792656607926),
#  ('person 15', 'bar 7', 'soda', 7.467219435609877),
#  ('person 15', 'bar 7', 'vodka', 47.559167791623615),
#  ('person 15', 'bar 7', 'whisky', 91.36447654338554),
#  ('person 16', 'bar 10', 'beer', 8.69366755662486),
#  ('person 16', 'bar 10', 'vodka', 41.91033443668857),
#  ('person 16', 'bar 10', 'wine', 206.86078639794144),
#  ('person 16', 'bar 11', 'beer', 6.242309574503452),
#  ('person 16', 'bar 11', 'cocktail', 22.64080404303968),
#  ('person 16', 'bar 11', 'whisky', 46.720566569129),
#  ('person 16', 'bar 12', 'whisky', 50.32640918623656),
#  ('person 16', 'bar 12', 'wine', 443.17386074643576),
#  ('person 16', 'bar 14', 'vodka', 57.02846114523709),
#  ('person 16', 'bar 14', 'wine', 304.05416238261387),
#  ('person 16', 'bar 3', 'beer', 4.634161106310785),
#  ('person 16', 'bar 3', 'soda', 7.087707950500771),
#  ('person 16', 'bar 3', 'whisky', 52.187310544541106),
#  ('person 16', 'bar 5', 'beer', 8.457143946550786),
#  ('person 16', 'bar 5', 'soda', 7.172601338941604),
#  ('person 16', 'bar 5', 'wine', 468.4320961767807),
#  ('person 16', 'bar 8', 'whisky', 45.60507479473017),
#  ('person 17', 'bar 1', 'wine', 313.7675603996031),
#  ('person 17', 'bar 10', 'vodka', 41.91033443668857),
#  ('person 17', 'bar 10', 'wine', 206.86078639794144),
#  ('person 17', 'bar 11', 'beer', 6.242309574503452),
#  ('person 17', 'bar 11', 'cocktail', 22.64080404303968),
#  ('person 17', 'bar 11', 'whisky', 46.720566569129),
#  ('person 17', 'bar 4', 'vodka', 34.62181418668479),
#  ('person 17', 'bar 4', 'vodka', 93.54708173545077),
#  ('person 17', 'bar 4', 'whisky', 65.86470233043656),
#  ('person 18', 'bar 13', 'cocktail', 26.30280829500407),
#  ('person 18', 'bar 13', 'wine', 289.89556255424395),
#  ('person 18', 'bar 13', 'wine', 411.3109796284698),
#  ('person 18', 'bar 15', 'cocktail', 25.87160057388246),
#  ('person 18', 'bar 17', 'beer', 4.947325653862208),
#  ('person 18', 'bar 17', 'whisky', 23.555515306070447),
#  ('person 18', 'bar 18', 'soda', 3.477885484928265),
#  ('person 18', 'bar 18', 'wine', 232.95805541472507),
#  ('person 18', 'bar 19', 'cocktail', 11.775652277283372),
#  ('person 18', 'bar 19', 'rum', 18.195812245830894),
#  ('person 18', 'bar 19', 'whisky', 34.50718138250522),
#  ('person 18', 'bar 20', 'beer', 7.961273210588843),
#  ('person 18', 'bar 20', 'rum', 9.153013579780236),
#  ('person 19', 'bar 10', 'vodka', 41.91033443668857),
#  ('person 19', 'bar 16', 'cocktail', 27.076269071549177),
#  ('person 19', 'bar 18', 'soda', 3.477885484928265),
#  ('person 19', 'bar 18', 'wine', 232.95805541472507),
#  ('person 19', 'bar 6', 'cocktail', 12.44799837935716),
#  ('person 19', 'bar 6', 'rum', 15.327792656607926),
#  ('person 19', 'bar 7', 'soda', 7.467219435609877),
#  ('person 19', 'bar 7', 'vodka', 47.559167791623615),
#  ('person 19', 'bar 7', 'whisky', 91.36447654338554),
#  ('person 19', 'bar 9', 'cocktail', 26.487211599014696),
#  ('person 19', 'bar 9', 'vodka', 99.06146339606494),
#  ('person 19', 'bar 9', 'whisky', 74.95702381711453),
#  ('person 2', 'bar 11', 'beer', 6.242309574503452),
#  ('person 2', 'bar 11', 'cocktail', 22.64080404303968),
#  ('person 2', 'bar 11', 'whisky', 46.720566569129),
#  ('person 2', 'bar 13', 'cocktail', 26.30280829500407),
#  ('person 2', 'bar 13', 'wine', 289.89556255424395),
#  ('person 2', 'bar 13', 'wine', 411.3109796284698),
#  ('person 2', 'bar 17', 'beer', 4.947325653862208),
#  ('person 2', 'bar 17', 'wine', 302.8571365196258),
#  ('person 2', 'bar 19', 'cocktail', 11.775652277283372),
#  ('person 2', 'bar 19', 'rum', 18.195812245830894),
#  ('person 2', 'bar 19', 'whisky', 34.50718138250522),
#  ('person 2', 'bar 5', 'beer', 8.457143946550786),
#  ('person 2', 'bar 5', 'soda', 7.172601338941604),
#  ('person 20', 'bar 1', 'cocktail', 17.112810402177274),
#  ('person 20', 'bar 1', 'whisky', 60.820202879840515),
#  ('person 20', 'bar 1', 'wine', 313.7675603996031),
#  ('person 20', 'bar 10', 'beer', 8.69366755662486),
#  ('person 20', 'bar 10', 'vodka', 41.91033443668857),
#  ('person 20', 'bar 12', 'cocktail', 26.84480233117938),
#  ('person 20', 'bar 13', 'cocktail', 26.30280829500407),
#  ('person 20', 'bar 13', 'wine', 289.89556255424395),
#  ('person 20', 'bar 13', 'wine', 411.3109796284698),
#  ('person 20', 'bar 14', 'vodka', 57.02846114523709),
#  ('person 20', 'bar 15', 'cocktail', 25.87160057388246),
#  ('person 20', 'bar 15', 'whisky', 53.23563067126088),
#  ('person 20', 'bar 15', 'wine', 144.248119993601),
#  ('person 20', 'bar 17', 'beer', 4.947325653862208),
#  ('person 20', 'bar 17', 'whisky', 23.555515306070447),
#  ('person 20', 'bar 17', 'wine', 302.8571365196258),
#  ('person 20', 'bar 18', 'soda', 3.477885484928265),
#  ('person 20', 'bar 18', 'vodka', 79.2083988361992),
#  ('person 20', 'bar 18', 'wine', 232.95805541472507),
#  ('person 20', 'bar 4', 'vodka', 34.62181418668479),
#  ('person 20', 'bar 4', 'vodka', 93.54708173545077),
#  ('person 20', 'bar 5', 'beer', 8.457143946550786),
#  ('person 20', 'bar 5', 'soda', 7.172601338941604),
#  ('person 20', 'bar 5', 'wine', 468.4320961767807),
#  ('person 20', 'bar 8', 'whisky', 20.28641964425333),
#  ('person 20', 'bar 8', 'wine', 263.50760182598606),
#  ('person 20', 'bar 9', 'cocktail', 26.487211599014696),
#  ('person 20', 'bar 9', 'vodka', 99.06146339606494),
#  ('person 20', 'bar 9', 'whisky', 74.95702381711453),
#  ('person 21', 'bar 1', 'cocktail', 17.112810402177274),
#  ('person 21', 'bar 1', 'whisky', 60.820202879840515),
#  ('person 21', 'bar 10', 'beer', 8.69366755662486),
#  ('person 21', 'bar 10', 'wine', 206.86078639794144),
#  ('person 21', 'bar 12', 'whisky', 50.32640918623656),
#  ('person 21', 'bar 12', 'wine', 443.17386074643576),
#  ('person 21', 'bar 13', 'cocktail', 26.30280829500407),
#  ('person 21', 'bar 13', 'wine', 289.89556255424395),
#  ('person 21', 'bar 13', 'wine', 411.3109796284698),
#  ('person 21', 'bar 17', 'beer', 4.947325653862208),
#  ('person 21', 'bar 17', 'whisky', 23.555515306070447),
#  ('person 21', 'bar 19', 'cocktail', 11.775652277283372),
#  ('person 21', 'bar 19', 'rum', 18.195812245830894),
#  ('person 21', 'bar 19', 'whisky', 34.50718138250522),
#  ('person 21', 'bar 20', 'beer', 6.543673591222614),
#  ('person 21', 'bar 20', 'rum', 9.153013579780236),
#  ('person 21', 'bar 5', 'beer', 8.457143946550786),
#  ('person 21', 'bar 8', 'whisky', 20.28641964425333),
#  ('person 21', 'bar 8', 'whisky', 45.60507479473017),
#  ('person 21', 'bar 9', 'cocktail', 26.487211599014696),
#  ('person 22', 'bar 10', 'beer', 8.69366755662486),
#  ('person 22', 'bar 10', 'vodka', 41.91033443668857),
#  ('person 22', 'bar 3', 'soda', 7.087707950500771),
#  ('person 22', 'bar 3', 'whisky', 52.187310544541106),
#  ('person 23', 'bar 10', 'beer', 8.69366755662486),
#  ('person 23', 'bar 10', 'vodka', 41.91033443668857),
#  ('person 23', 'bar 10', 'wine', 206.86078639794144),
#  ('person 23', 'bar 11', 'beer', 6.242309574503452),
#  ('person 23', 'bar 11', 'cocktail', 22.64080404303968),
#  ('person 23', 'bar 12', 'cocktail', 26.84480233117938),
#  ('person 23', 'bar 12', 'whisky', 50.32640918623656),
#  ('person 23', 'bar 12', 'wine', 443.17386074643576),
#  ('person 23', 'bar 15', 'cocktail', 25.87160057388246),
#  ('person 23', 'bar 15', 'whisky', 53.23563067126088),
#  ('person 23', 'bar 15', 'wine', 144.248119993601),
#  ('person 23', 'bar 16', 'cocktail', 27.076269071549177),
#  ('person 23', 'bar 16', 'soda', 8.259685171069577),
#  ('person 23', 'bar 16', 'wine', 478.06815632339567),
#  ('person 23', 'bar 17', 'beer', 4.947325653862208),
#  ('person 23', 'bar 17', 'whisky', 23.555515306070447),
#  ('person 23', 'bar 19', 'cocktail', 11.775652277283372),
#  ('person 23', 'bar 19', 'rum', 18.195812245830894),
#  ('person 23', 'bar 19', 'whisky', 34.50718138250522),
#  ('person 23', 'bar 2', 'beer', 7.54580516833812),
#  ('person 23', 'bar 2', 'rum', 6.4497588458471),
#  ('person 23', 'bar 20', 'beer', 6.543673591222614),
#  ('person 23', 'bar 20', 'beer', 7.961273210588843),
#  ('person 23', 'bar 20', 'rum', 9.153013579780236),
#  ('person 23', 'bar 4', 'vodka', 34.62181418668479),
#  ('person 23', 'bar 4', 'vodka', 93.54708173545077),
#  ('person 23', 'bar 4', 'whisky', 65.86470233043656),
#  ('person 23', 'bar 7', 'vodka', 47.559167791623615),
#  ('person 23', 'bar 7', 'whisky', 91.36447654338554),
#  ('person 23', 'bar 8', 'whisky', 45.60507479473017),
#  ('person 23', 'bar 8', 'wine', 263.50760182598606),
#  ('person 23', 'bar 9', 'cocktail', 26.487211599014696),
#  ('person 23', 'bar 9', 'vodka', 99.06146339606494),
#  ('person 23', 'bar 9', 'whisky', 74.95702381711453),
#  ('person 24', 'bar 10', 'beer', 8.69366755662486),
#  ('person 24', 'bar 10', 'vodka', 41.91033443668857),
#  ('person 24', 'bar 10', 'wine', 206.86078639794144),
#  ('person 24', 'bar 19', 'cocktail', 11.775652277283372),
#  ('person 24', 'bar 19', 'rum', 18.195812245830894),
#  ('person 24', 'bar 2', 'beer', 7.54580516833812),
#  ('person 24', 'bar 2', 'cocktail', 18.34535005968064),
#  ('person 24', 'bar 3', 'soda', 7.087707950500771),
#  ('person 24', 'bar 3', 'whisky', 52.187310544541106),
#  ('person 24', 'bar 8', 'whisky', 20.28641964425333),
#  ('person 24', 'bar 8', 'whisky', 45.60507479473017),
#  ('person 25', 'bar 1', 'cocktail', 17.112810402177274),
#  ('person 25', 'bar 1', 'whisky', 60.820202879840515),
#  ('person 25', 'bar 1', 'wine', 313.7675603996031),
#  ('person 25', 'bar 10', 'beer', 8.69366755662486),
#  ('person 25', 'bar 10', 'vodka', 41.91033443668857),
#  ('person 25', 'bar 11', 'beer', 6.242309574503452),
#  ('person 25', 'bar 11', 'cocktail', 22.64080404303968),
#  ('person 25', 'bar 11', 'whisky', 46.720566569129),
#  ('person 25', 'bar 12', 'whisky', 50.32640918623656),
#  ('person 25', 'bar 13', 'wine', 289.89556255424395),
#  ('person 25', 'bar 13', 'wine', 411.3109796284698),
#  ('person 25', 'bar 14', 'vodka', 57.02846114523709),
#  ('person 25', 'bar 14', 'wine', 6.28380866907537),
#  ('person 25', 'bar 14', 'wine', 304.05416238261387),
#  ('person 25', 'bar 16', 'cocktail', 27.076269071549177),
#  ('person 25', 'bar 16', 'soda', 8.259685171069577),
#  ('person 25', 'bar 20', 'beer', 6.543673591222614),
#  ('person 25', 'bar 20', 'beer', 7.961273210588843),
#  ('person 25', 'bar 20', 'rum', 9.153013579780236),
#  ('person 25', 'bar 4', 'vodka', 34.62181418668479),
#  ('person 25', 'bar 4', 'vodka', 93.54708173545077),
#  ('person 25', 'bar 4', 'whisky', 65.86470233043656),
#  ('person 25', 'bar 7', 'vodka', 47.559167791623615),
#  ('person 25', 'bar 7', 'whisky', 91.36447654338554),
#  ('person 25', 'bar 9', 'vodka', 99.06146339606494),
#  ('person 25', 'bar 9', 'whisky', 74.95702381711453),
#  ('person 26', 'bar 1', 'cocktail', 17.112810402177274),
#  ('person 26', 'bar 1', 'wine', 313.7675603996031),
#  ('person 26', 'bar 11', 'cocktail', 22.64080404303968),
#  ('person 26', 'bar 11', 'whisky', 46.720566569129),
#  ('person 26', 'bar 13', 'cocktail', 26.30280829500407),
#  ('person 26', 'bar 13', 'wine', 289.89556255424395),
#  ('person 26', 'bar 13', 'wine', 411.3109796284698),
#  ('person 26', 'bar 15', 'cocktail', 25.87160057388246),
#  ('person 26', 'bar 15', 'whisky', 53.23563067126088),
#  ('person 26', 'bar 15', 'wine', 144.248119993601),
#  ('person 26', 'bar 16', 'cocktail', 27.076269071549177),
#  ('person 26', 'bar 16', 'wine', 478.06815632339567),
#  ('person 26', 'bar 18', 'soda', 3.477885484928265),
#  ('person 26', 'bar 18', 'vodka', 79.2083988361992),
#  ('person 26', 'bar 18', 'wine', 232.95805541472507),
#  ('person 26', 'bar 2', 'beer', 7.54580516833812),
#  ('person 26', 'bar 5', 'beer', 8.457143946550786),
#  ('person 26', 'bar 5', 'soda', 7.172601338941604),
#  ('person 26', 'bar 6', 'cocktail', 12.44799837935716),
#  ('person 26', 'bar 6', 'whisky', 55.271910273004316),
#  ('person 26', 'bar 8', 'whisky', 45.60507479473017),
#  ('person 26', 'bar 8', 'wine', 263.50760182598606),
#  ('person 27', 'bar 3', 'beer', 4.634161106310785),
#  ('person 27', 'bar 3', 'soda', 7.087707950500771),
#  ('person 27', 'bar 3', 'whisky', 52.187310544541106),
#  ('person 27', 'bar 8', 'whisky', 20.28641964425333),
#  ('person 27', 'bar 8', 'wine', 263.50760182598606),
#  ('person 27', 'bar 9', 'cocktail', 26.487211599014696),
#  ('person 27', 'bar 9', 'whisky', 74.95702381711453),
#  ('person 28', 'bar 1', 'cocktail', 17.112810402177274),
#  ('person 28', 'bar 12', 'cocktail', 26.84480233117938),
#  ('person 28', 'bar 12', 'whisky', 50.32640918623656),
#  ('person 28', 'bar 18', 'vodka', 79.2083988361992),
#  ('person 28', 'bar 19', 'cocktail', 11.775652277283372),
#  ('person 28', 'bar 19', 'rum', 18.195812245830894),
#  ('person 28', 'bar 19', 'whisky', 34.50718138250522),
#  ('person 28', 'bar 20', 'rum', 9.153013579780236),
#  ('person 28', 'bar 5', 'soda', 7.172601338941604),
#  ('person 29', 'bar 1', 'cocktail', 17.112810402177274),
#  ('person 29', 'bar 1', 'whisky', 60.820202879840515),
#  ('person 29', 'bar 10', 'beer', 8.69366755662486),
#  ('person 29', 'bar 10', 'vodka', 41.91033443668857),
#  ('person 29', 'bar 10', 'wine', 206.86078639794144),
#  ('person 29', 'bar 11', 'cocktail', 22.64080404303968),
#  ('person 29', 'bar 11', 'whisky', 46.720566569129),
#  ('person 29', 'bar 14', 'vodka', 57.02846114523709),
#  ('person 29', 'bar 14', 'wine', 304.05416238261387),
#  ('person 29', 'bar 15', 'cocktail', 25.87160057388246),
#  ('person 29', 'bar 15', 'whisky', 53.23563067126088),
#  ('person 29', 'bar 15', 'wine', 144.248119993601),
#  ('person 29', 'bar 17', 'beer', 4.947325653862208),
#  ('person 29', 'bar 17', 'whisky', 23.555515306070447),
#  ('person 29', 'bar 18', 'soda', 3.477885484928265),
#  ('person 29', 'bar 18', 'vodka', 79.2083988361992),
#  ('person 29', 'bar 18', 'wine', 232.95805541472507),
#  ('person 29', 'bar 19', 'cocktail', 11.775652277283372),
#  ('person 29', 'bar 19', 'rum', 18.195812245830894),
#  ('person 29', 'bar 3', 'soda', 7.087707950500771),
#  ('person 29', 'bar 3', 'whisky', 52.187310544541106),
#  ('person 29', 'bar 4', 'vodka', 93.54708173545077),
#  ('person 29', 'bar 6', 'cocktail', 12.44799837935716),
#  ('person 29', 'bar 6', 'rum', 15.327792656607926),
#  ('person 29', 'bar 6', 'whisky', 55.271910273004316),
#  ('person 29', 'bar 8', 'whisky', 20.28641964425333),
#  ('person 29', 'bar 8', 'whisky', 45.60507479473017),
#  ('person 29', 'bar 8', 'wine', 263.50760182598606),
#  ('person 3', 'bar 13', 'cocktail', 26.30280829500407),
#  ('person 3', 'bar 13', 'wine', 289.89556255424395),
#  ('person 3', 'bar 13', 'wine', 411.3109796284698),
#  ('person 3', 'bar 15', 'cocktail', 25.87160057388246),
#  ('person 3', 'bar 15', 'whisky', 53.23563067126088),
#  ('person 3', 'bar 15', 'wine', 144.248119993601),
#  ('person 3', 'bar 17', 'beer', 4.947325653862208),
#  ('person 3', 'bar 17', 'whisky', 23.555515306070447),
#  ('person 3', 'bar 17', 'wine', 302.8571365196258),
#  ('person 3', 'bar 2', 'beer', 7.54580516833812),
#  ('person 3', 'bar 20', 'beer', 6.543673591222614),
#  ('person 3', 'bar 20', 'beer', 7.961273210588843),
#  ('person 3', 'bar 20', 'rum', 9.153013579780236),
#  ('person 3', 'bar 6', 'cocktail', 12.44799837935716),
#  ('person 3', 'bar 6', 'rum', 15.327792656607926),
#  ('person 3', 'bar 6', 'whisky', 55.271910273004316),
#  ('person 3', 'bar 7', 'soda', 7.467219435609877),
#  ('person 3', 'bar 7', 'vodka', 47.559167791623615),
#  ('person 3', 'bar 7', 'whisky', 91.36447654338554),
#  ('person 30', 'bar 4', 'vodka', 34.62181418668479),
#  ('person 30', 'bar 4', 'vodka', 93.54708173545077),
#  ('person 30', 'bar 4', 'whisky', 65.86470233043656),
#  ('person 31', 'bar 11', 'beer', 6.242309574503452),
#  ('person 31', 'bar 11', 'cocktail', 22.64080404303968),
#  ('person 31', 'bar 13', 'cocktail', 26.30280829500407),
#  ('person 31', 'bar 13', 'wine', 289.89556255424395),
#  ('person 31', 'bar 15', 'cocktail', 25.87160057388246),
#  ('person 31', 'bar 15', 'wine', 144.248119993601),
#  ('person 31', 'bar 4', 'vodka', 34.62181418668479),
#  ('person 31', 'bar 4', 'vodka', 93.54708173545077),
#  ('person 31', 'bar 4', 'whisky', 65.86470233043656),
#  ('person 31', 'bar 5', 'beer', 8.457143946550786),
#  ('person 31', 'bar 5', 'soda', 7.172601338941604),
#  ('person 31', 'bar 5', 'wine', 468.4320961767807),
#  ('person 31', 'bar 8', 'whisky', 20.28641964425333),
#  ('person 31', 'bar 8', 'whisky', 45.60507479473017),
#  ('person 31', 'bar 8', 'wine', 263.50760182598606),
#  ('person 32', 'bar 10', 'beer', 8.69366755662486),
#  ('person 32', 'bar 10', 'vodka', 41.91033443668857),
#  ('person 32', 'bar 10', 'wine', 206.86078639794144),
#  ('person 32', 'bar 18', 'soda', 3.477885484928265),
#  ('person 32', 'bar 18', 'vodka', 79.2083988361992),
#  ('person 32', 'bar 18', 'wine', 232.95805541472507),
#  ('person 32', 'bar 7', 'soda', 7.467219435609877),
#  ('person 32', 'bar 7', 'vodka', 47.559167791623615),
#  ('person 32', 'bar 7', 'whisky', 91.36447654338554),
#  ('person 33', 'bar 13', 'wine', 289.89556255424395),
#  ('person 33', 'bar 13', 'wine', 411.3109796284698),
#  ('person 33', 'bar 20', 'beer', 6.543673591222614),
#  ('person 33', 'bar 20', 'beer', 7.961273210588843),
#  ('person 33', 'bar 5', 'beer', 8.457143946550786),
#  ('person 33', 'bar 5', 'soda', 7.172601338941604),
#  ('person 33', 'bar 6', 'cocktail', 12.44799837935716),
#  ('person 33', 'bar 9', 'cocktail', 26.487211599014696),
#  ('person 33', 'bar 9', 'whisky', 74.95702381711453),
#  ('person 34', 'bar 16', 'cocktail', 27.076269071549177),
#  ('person 34', 'bar 16', 'wine', 478.06815632339567),
#  ('person 34', 'bar 17', 'beer', 4.947325653862208),
#  ('person 34', 'bar 17', 'whisky', 23.555515306070447),
#  ('person 34', 'bar 17', 'wine', 302.8571365196258),
#  ('person 34', 'bar 3', 'soda', 7.087707950500771),
#  ('person 34', 'bar 3', 'whisky', 52.187310544541106),
#  ('person 34', 'bar 6', 'cocktail', 12.44799837935716),
#  ('person 34', 'bar 6', 'rum', 15.327792656607926),
#  ('person 34', 'bar 6', 'whisky', 55.271910273004316),
#  ('person 34', 'bar 7', 'vodka', 47.559167791623615),
#  ('person 35', 'bar 1', 'whisky', 60.820202879840515),
#  ('person 35', 'bar 1', 'wine', 313.7675603996031),
#  ('person 35', 'bar 10', 'beer', 8.69366755662486),
#  ('person 35', 'bar 10', 'wine', 206.86078639794144),
#  ('person 35', 'bar 11', 'beer', 6.242309574503452),
#  ('person 35', 'bar 11', 'cocktail', 22.64080404303968),
#  ('person 35', 'bar 16', 'cocktail', 27.076269071549177),
#  ('person 35', 'bar 16', 'soda', 8.259685171069577),
#  ('person 35', 'bar 16', 'wine', 478.06815632339567),
#  ('person 35', 'bar 19', 'cocktail', 11.775652277283372),
#  ('person 35', 'bar 19', 'rum', 18.195812245830894),
#  ('person 35', 'bar 19', 'whisky', 34.50718138250522),
#  ('person 35', 'bar 2', 'beer', 7.54580516833812),
#  ('person 35', 'bar 2', 'cocktail', 18.34535005968064),
#  ('person 35', 'bar 2', 'rum', 6.4497588458471),
#  ('person 35', 'bar 20', 'beer', 7.961273210588843),
#  ('person 35', 'bar 20', 'rum', 9.153013579780236),
#  ('person 35', 'bar 3', 'beer', 4.634161106310785),
#  ('person 35', 'bar 3', 'soda', 7.087707950500771),
#  ('person 35', 'bar 3', 'whisky', 52.187310544541106),
#  ('person 35', 'bar 4', 'vodka', 93.54708173545077),
#  ('person 35', 'bar 4', 'whisky', 65.86470233043656),
#  ('person 35', 'bar 6', 'cocktail', 12.44799837935716),
#  ('person 35', 'bar 6', 'rum', 15.327792656607926),
#  ('person 35', 'bar 6', 'whisky', 55.271910273004316),
#  ('person 36', 'bar 10', 'beer', 8.69366755662486),
#  ('person 36', 'bar 10', 'vodka', 41.91033443668857),
#  ('person 36', 'bar 10', 'wine', 206.86078639794144),
#  ('person 36', 'bar 12', 'whisky', 50.32640918623656),
#  ('person 36', 'bar 12', 'wine', 443.17386074643576),
#  ('person 36', 'bar 14', 'vodka', 57.02846114523709),
#  ('person 36', 'bar 14', 'wine', 6.28380866907537),
#  ('person 36', 'bar 14', 'wine', 304.05416238261387),
#  ('person 36', 'bar 16', 'soda', 8.259685171069577),
#  ('person 36', 'bar 16', 'wine', 478.06815632339567),
#  ('person 36', 'bar 20', 'beer', 6.543673591222614),
#  ('person 36', 'bar 20', 'beer', 7.961273210588843),
#  ('person 36', 'bar 20', 'rum', 9.153013579780236),
#  ('person 36', 'bar 4', 'vodka', 34.62181418668479),
#  ('person 36', 'bar 4', 'vodka', 93.54708173545077),
#  ('person 36', 'bar 4', 'whisky', 65.86470233043656),
#  ('person 36', 'bar 5', 'beer', 8.457143946550786),
#  ('person 36', 'bar 5', 'soda', 7.172601338941604),
#  ('person 36', 'bar 6', 'cocktail', 12.44799837935716),
#  ('person 36', 'bar 7', 'vodka', 47.559167791623615),
#  ('person 36', 'bar 9', 'cocktail', 26.487211599014696),
#  ('person 36', 'bar 9', 'whisky', 74.95702381711453),
#  ('person 37', 'bar 1', 'cocktail', 17.112810402177274),
#  ('person 37', 'bar 1', 'whisky', 60.820202879840515),
#  ('person 37', 'bar 1', 'wine', 313.7675603996031),
#  ('person 37', 'bar 10', 'wine', 206.86078639794144),
#  ('person 37', 'bar 11', 'whisky', 46.720566569129),
#  ('person 37', 'bar 12', 'cocktail', 26.84480233117938),
#  ('person 37', 'bar 12', 'whisky', 50.32640918623656),
#  ('person 37', 'bar 12', 'wine', 443.17386074643576),
#  ('person 37', 'bar 16', 'cocktail', 27.076269071549177),
#  ('person 37', 'bar 16', 'wine', 478.06815632339567),
#  ('person 37', 'bar 3', 'soda', 7.087707950500771),
#  ('person 37', 'bar 6', 'cocktail', 12.44799837935716),
#  ('person 37', 'bar 6', 'rum', 15.327792656607926),
#  ('person 37', 'bar 7', 'vodka', 47.559167791623615),
#  ('person 37', 'bar 9', 'whisky', 74.95702381711453),
#  ('person 38', 'bar 10', 'beer', 8.69366755662486),
#  ('person 38', 'bar 10', 'vodka', 41.91033443668857),
#  ('person 38', 'bar 11', 'cocktail', 22.64080404303968),
#  ('person 38', 'bar 11', 'whisky', 46.720566569129),
#  ('person 38', 'bar 12', 'cocktail', 26.84480233117938),
#  ('person 38', 'bar 12', 'wine', 443.17386074643576),
#  ('person 38', 'bar 13', 'wine', 289.89556255424395),
#  ('person 38', 'bar 13', 'wine', 411.3109796284698),
#  ('person 38', 'bar 19', 'cocktail', 11.775652277283372),
#  ('person 38', 'bar 19', 'whisky', 34.50718138250522),
#  ('person 38', 'bar 3', 'beer', 4.634161106310785),
#  ('person 38', 'bar 3', 'whisky', 52.187310544541106),
#  ('person 38', 'bar 4', 'whisky', 65.86470233043656),
#  ('person 38', 'bar 6', 'rum', 15.327792656607926),
#  ('person 38', 'bar 6', 'whisky', 55.271910273004316),
#  ('person 38', 'bar 8', 'whisky', 20.28641964425333),
#  ('person 38', 'bar 8', 'whisky', 45.60507479473017),
#  ('person 39', 'bar 13', 'cocktail', 26.30280829500407),
#  ('person 39', 'bar 13', 'wine', 289.89556255424395),
#  ('person 39', 'bar 13', 'wine', 411.3109796284698),
#  ('person 39', 'bar 14', 'vodka', 57.02846114523709),
#  ('person 39', 'bar 14', 'wine', 6.28380866907537),
#  ('person 39', 'bar 14', 'wine', 304.05416238261387),
#  ('person 4', 'bar 2', 'beer', 7.54580516833812),
#  ('person 4', 'bar 5', 'beer', 8.457143946550786),
#  ('person 4', 'bar 5', 'soda', 7.172601338941604),
#  ('person 4', 'bar 5', 'wine', 468.4320961767807),
#  ('person 4', 'bar 8', 'whisky', 20.28641964425333),
#  ('person 4', 'bar 8', 'whisky', 45.60507479473017),
#  ('person 40', 'bar 1', 'cocktail', 17.112810402177274),
#  ('person 40', 'bar 1', 'whisky', 60.820202879840515),
#  ('person 40', 'bar 11', 'beer', 6.242309574503452),
#  ('person 40', 'bar 11', 'cocktail', 22.64080404303968),
#  ('person 40', 'bar 15', 'cocktail', 25.87160057388246),
#  ('person 40', 'bar 15', 'whisky', 53.23563067126088),
#  ('person 40', 'bar 15', 'wine', 144.248119993601),
#  ('person 40', 'bar 19', 'rum', 18.195812245830894),
#  ('person 40', 'bar 20', 'beer', 6.543673591222614),
#  ('person 40', 'bar 20', 'rum', 9.153013579780236),
#  ('person 40', 'bar 6', 'cocktail', 12.44799837935716),
#  ('person 40', 'bar 6', 'whisky', 55.271910273004316),
#  ('person 40', 'bar 7', 'soda', 7.467219435609877),
#  ('person 40', 'bar 7', 'vodka', 47.559167791623615),
#  ('person 40', 'bar 7', 'whisky', 91.36447654338554),
#  ('person 40', 'bar 9', 'cocktail', 26.487211599014696),
#  ('person 41', 'bar 1', 'cocktail', 17.112810402177274),
#  ('person 41', 'bar 1', 'whisky', 60.820202879840515),
#  ('person 41', 'bar 1', 'wine', 313.7675603996031),
#  ('person 41', 'bar 14', 'vodka', 57.02846114523709),
#  ('person 41', 'bar 14', 'wine', 6.28380866907537),
#  ('person 41', 'bar 14', 'wine', 304.05416238261387),
#  ('person 41', 'bar 19', 'cocktail', 11.775652277283372),
#  ('person 41', 'bar 19', 'rum', 18.195812245830894),
#  ('person 41', 'bar 19', 'whisky', 34.50718138250522),
#  ('person 41', 'bar 8', 'wine', 263.50760182598606),
#  ('person 42', 'bar 10', 'beer', 8.69366755662486),
#  ('person 42', 'bar 10', 'vodka', 41.91033443668857),
#  ('person 42', 'bar 10', 'wine', 206.86078639794144),
#  ('person 42', 'bar 11', 'cocktail', 22.64080404303968),
#  ('person 42', 'bar 11', 'whisky', 46.720566569129),
#  ('person 42', 'bar 12', 'cocktail', 26.84480233117938),
#  ('person 42', 'bar 12', 'whisky', 50.32640918623656),
#  ('person 42', 'bar 12', 'wine', 443.17386074643576),
#  ('person 42', 'bar 16', 'cocktail', 27.076269071549177),
#  ('person 42', 'bar 16', 'soda', 8.259685171069577),
#  ('person 42', 'bar 16', 'wine', 478.06815632339567),
#  ('person 42', 'bar 17', 'beer', 4.947325653862208),
#  ('person 42', 'bar 17', 'whisky', 23.555515306070447),
#  ('person 42', 'bar 17', 'wine', 302.8571365196258),
#  ('person 42', 'bar 20', 'beer', 6.543673591222614),
#  ('person 42', 'bar 20', 'beer', 7.961273210588843),
#  ('person 42', 'bar 20', 'rum', 9.153013579780236),
#  ('person 42', 'bar 4', 'vodka', 34.62181418668479),
#  ('person 42', 'bar 4', 'vodka', 93.54708173545077),
#  ('person 42', 'bar 4', 'whisky', 65.86470233043656),
#  ('person 42', 'bar 7', 'soda', 7.467219435609877),
#  ('person 42', 'bar 7', 'vodka', 47.559167791623615),
#  ('person 42', 'bar 7', 'whisky', 91.36447654338554),
#  ('person 43', 'bar 15', 'cocktail', 25.87160057388246),
#  ('person 43', 'bar 15', 'whisky', 53.23563067126088),
#  ('person 43', 'bar 15', 'wine', 144.248119993601),
#  ('person 43', 'bar 16', 'cocktail', 27.076269071549177),
#  ('person 43', 'bar 16', 'soda', 8.259685171069577),
#  ('person 43', 'bar 16', 'wine', 478.06815632339567),
#  ('person 43', 'bar 2', 'beer', 7.54580516833812),
#  ('person 43', 'bar 2', 'rum', 6.4497588458471),
#  ('person 43', 'bar 20', 'beer', 6.543673591222614),
#  ('person 43', 'bar 20', 'beer', 7.961273210588843),
#  ('person 43', 'bar 20', 'rum', 9.153013579780236),
#  ('person 43', 'bar 3', 'beer', 4.634161106310785),
#  ('person 43', 'bar 3', 'soda', 7.087707950500771),
#  ('person 43', 'bar 3', 'whisky', 52.187310544541106),
#  ('person 44', 'bar 1', 'whisky', 60.820202879840515),
#  ('person 44', 'bar 1', 'wine', 313.7675603996031),
#  ('person 44', 'bar 15', 'whisky', 53.23563067126088),
#  ('person 44', 'bar 18', 'soda', 3.477885484928265),
#  ('person 44', 'bar 18', 'vodka', 79.2083988361992),
#  ('person 44', 'bar 18', 'wine', 232.95805541472507),
#  ('person 44', 'bar 19', 'cocktail', 11.775652277283372),
#  ('person 44', 'bar 19', 'rum', 18.195812245830894),
#  ('person 44', 'bar 19', 'whisky', 34.50718138250522),
#  ('person 44', 'bar 2', 'beer', 7.54580516833812),
#  ('person 44', 'bar 2', 'cocktail', 18.34535005968064),
#  ('person 44', 'bar 2', 'rum', 6.4497588458471),
#  ('person 44', 'bar 9', 'vodka', 99.06146339606494),
#  ('person 44', 'bar 9', 'whisky', 74.95702381711453),
#  ('person 45', 'bar 13', 'cocktail', 26.30280829500407),
#  ('person 45', 'bar 13', 'wine', 289.89556255424395),
#  ('person 45', 'bar 13', 'wine', 411.3109796284698),
#  ('person 45', 'bar 14', 'vodka', 57.02846114523709),
#  ('person 45', 'bar 14', 'wine', 6.28380866907537),
#  ('person 45', 'bar 14', 'wine', 304.05416238261387),
#  ('person 45', 'bar 15', 'cocktail', 25.87160057388246),
#  ('person 45', 'bar 15', 'whisky', 53.23563067126088),
#  ('person 45', 'bar 17', 'beer', 4.947325653862208),
#  ('person 45', 'bar 17', 'whisky', 23.555515306070447),
#  ('person 45', 'bar 17', 'wine', 302.8571365196258),
#  ('person 45', 'bar 2', 'beer', 7.54580516833812),
#  ('person 45', 'bar 2', 'cocktail', 18.34535005968064),
#  ('person 45', 'bar 2', 'rum', 6.4497588458471),
#  ('person 45', 'bar 20', 'beer', 6.543673591222614),
#  ('person 45', 'bar 20', 'rum', 9.153013579780236),
#  ('person 45', 'bar 3', 'beer', 4.634161106310785),
#  ('person 45', 'bar 3', 'whisky', 52.187310544541106),
#  ('person 45', 'bar 4', 'vodka', 34.62181418668479),
#  ('person 45', 'bar 4', 'vodka', 93.54708173545077),
#  ('person 45', 'bar 5', 'soda', 7.172601338941604),
#  ('person 45', 'bar 5', 'wine', 468.4320961767807),
#  ('person 45', 'bar 6', 'rum', 15.327792656607926),
#  ('person 45', 'bar 6', 'whisky', 55.271910273004316),
#  ('person 45', 'bar 8', 'whisky', 45.60507479473017),
#  ('person 45', 'bar 8', 'wine', 263.50760182598606),
#  ('person 46', 'bar 1', 'cocktail', 17.112810402177274),
#  ('person 46', 'bar 1', 'whisky', 60.820202879840515),
#  ('person 46', 'bar 1', 'wine', 313.7675603996031),
#  ('person 46', 'bar 15', 'cocktail', 25.87160057388246),
#  ('person 46', 'bar 15', 'whisky', 53.23563067126088),
#  ('person 46', 'bar 15', 'wine', 144.248119993601),
#  ('person 46', 'bar 16', 'cocktail', 27.076269071549177),
#  ('person 46', 'bar 16', 'soda', 8.259685171069577),
#  ('person 46', 'bar 18', 'soda', 3.477885484928265),
#  ('person 46', 'bar 18', 'vodka', 79.2083988361992),
#  ('person 46', 'bar 18', 'wine', 232.95805541472507),
#  ('person 46', 'bar 2', 'beer', 7.54580516833812),
#  ('person 46', 'bar 2', 'cocktail', 18.34535005968064),
#  ('person 46', 'bar 2', 'rum', 6.4497588458471),
#  ('person 47', 'bar 11', 'beer', 6.242309574503452),
#  ('person 47', 'bar 11', 'cocktail', 22.64080404303968),
#  ('person 47', 'bar 11', 'whisky', 46.720566569129),
#  ('person 47', 'bar 12', 'cocktail', 26.84480233117938),
#  ('person 47', 'bar 12', 'whisky', 50.32640918623656),
#  ('person 47', 'bar 12', 'wine', 443.17386074643576),
#  ('person 47', 'bar 16', 'cocktail', 27.076269071549177),
#  ('person 47', 'bar 20', 'beer', 7.961273210588843),
#  ('person 47', 'bar 20', 'rum', 9.153013579780236),
#  ('person 47', 'bar 6', 'cocktail', 12.44799837935716),
#  ('person 47', 'bar 6', 'rum', 15.327792656607926),
#  ('person 47', 'bar 7', 'soda', 7.467219435609877),
#  ('person 47', 'bar 7', 'vodka', 47.559167791623615),
#  ('person 48', 'bar 10', 'beer', 8.69366755662486),
#  ('person 48', 'bar 11', 'beer', 6.242309574503452),
#  ('person 48', 'bar 11', 'cocktail', 22.64080404303968),
#  ('person 48', 'bar 14', 'vodka', 57.02846114523709),
#  ('person 48', 'bar 14', 'wine', 6.28380866907537),
#  ('person 48', 'bar 14', 'wine', 304.05416238261387),
#  ('person 48', 'bar 15', 'cocktail', 25.87160057388246),
#  ('person 48', 'bar 15', 'whisky', 53.23563067126088),
#  ('person 48', 'bar 15', 'wine', 144.248119993601),
#  ('person 48', 'bar 18', 'soda', 3.477885484928265),
#  ('person 48', 'bar 18', 'vodka', 79.2083988361992),
#  ('person 48', 'bar 18', 'wine', 232.95805541472507),
#  ('person 48', 'bar 2', 'beer', 7.54580516833812),
#  ('person 48', 'bar 2', 'cocktail', 18.34535005968064),
#  ('person 48', 'bar 2', 'rum', 6.4497588458471),
#  ('person 48', 'bar 3', 'beer', 4.634161106310785),
#  ('person 48', 'bar 3', 'soda', 7.087707950500771),
#  ('person 48', 'bar 6', 'cocktail', 12.44799837935716),
#  ('person 48', 'bar 6', 'rum', 15.327792656607926),
#  ('person 49', 'bar 1', 'cocktail', 17.112810402177274),
#  ('person 49', 'bar 14', 'vodka', 57.02846114523709),
#  ('person 49', 'bar 2', 'cocktail', 18.34535005968064),
#  ('person 49', 'bar 2', 'rum', 6.4497588458471),
#  ('person 49', 'bar 20', 'beer', 6.543673591222614),
#  ('person 49', 'bar 20', 'beer', 7.961273210588843),
#  ('person 49', 'bar 20', 'rum', 9.153013579780236),
#  ('person 49', 'bar 5', 'beer', 8.457143946550786),
#  ('person 49', 'bar 6', 'cocktail', 12.44799837935716),
#  ('person 49', 'bar 6', 'rum', 15.327792656607926),
#  ('person 49', 'bar 6', 'whisky', 55.271910273004316),
#  ('person 5', 'bar 14', 'vodka', 57.02846114523709),
#  ('person 5', 'bar 14', 'wine', 6.28380866907537),
#  ('person 5', 'bar 14', 'wine', 304.05416238261387),
#  ('person 5', 'bar 15', 'wine', 144.248119993601),
#  ('person 5', 'bar 16', 'cocktail', 27.076269071549177),
#  ('person 5', 'bar 16', 'soda', 8.259685171069577),
#  ('person 5', 'bar 17', 'beer', 4.947325653862208),
#  ('person 5', 'bar 17', 'whisky', 23.555515306070447),
#  ('person 5', 'bar 17', 'wine', 302.8571365196258),
#  ('person 5', 'bar 19', 'rum', 18.195812245830894),
#  ('person 5', 'bar 19', 'whisky', 34.50718138250522),
#  ('person 5', 'bar 20', 'beer', 6.543673591222614),
#  ('person 5', 'bar 20', 'rum', 9.153013579780236),
#  ('person 5', 'bar 3', 'beer', 4.634161106310785),
#  ('person 5', 'bar 4', 'vodka', 34.62181418668479),
#  ('person 5', 'bar 4', 'vodka', 93.54708173545077),
#  ('person 5', 'bar 4', 'whisky', 65.86470233043656),
#  ('person 5', 'bar 8', 'whisky', 20.28641964425333),
#  ('person 5', 'bar 8', 'wine', 263.50760182598606),
#  ('person 50', 'bar 11', 'whisky', 46.720566569129),
#  ('person 50', 'bar 13', 'cocktail', 26.30280829500407),
#  ('person 50', 'bar 13', 'wine', 289.89556255424395),
#  ('person 50', 'bar 15', 'cocktail', 25.87160057388246),
#  ('person 50', 'bar 15', 'whisky', 53.23563067126088),
#  ('person 50', 'bar 16', 'cocktail', 27.076269071549177),
#  ('person 50', 'bar 16', 'wine', 478.06815632339567),
#  ('person 50', 'bar 17', 'beer', 4.947325653862208),
#  ('person 50', 'bar 17', 'wine', 302.8571365196258),
#  ('person 50', 'bar 18', 'soda', 3.477885484928265),
#  ('person 50', 'bar 18', 'vodka', 79.2083988361992),
#  ('person 50', 'bar 18', 'wine', 232.95805541472507),
#  ('person 50', 'bar 20', 'beer', 6.543673591222614),
#  ('person 50', 'bar 20', 'beer', 7.961273210588843),
#  ('person 50', 'bar 20', 'rum', 9.153013579780236),
#  ('person 50', 'bar 3', 'beer', 4.634161106310785),
#  ('person 50', 'bar 3', 'soda', 7.087707950500771),
#  ('person 50', 'bar 3', 'whisky', 52.187310544541106),
#  ('person 50', 'bar 4', 'whisky', 65.86470233043656),
#  ('person 50', 'bar 5', 'soda', 7.172601338941604),
#  ('person 50', 'bar 5', 'wine', 468.4320961767807),
#  ('person 50', 'bar 6', 'cocktail', 12.44799837935716),
#  ('person 50', 'bar 6', 'rum', 15.327792656607926),
#  ('person 50', 'bar 6', 'whisky', 55.271910273004316),
#  ('person 50', 'bar 7', 'soda', 7.467219435609877),
#  ('person 50', 'bar 7', 'whisky', 91.36447654338554),
#  ('person 50', 'bar 8', 'whisky', 20.28641964425333),
#  ('person 50', 'bar 8', 'whisky', 45.60507479473017),
#  ('person 50', 'bar 9', 'cocktail', 26.487211599014696),
#  ('person 50', 'bar 9', 'vodka', 99.06146339606494),
#  ('person 50', 'bar 9', 'whisky', 74.95702381711453),
#  ('person 51', 'bar 13', 'cocktail', 26.30280829500407),
#  ('person 51', 'bar 13', 'wine', 411.3109796284698),
#  ('person 51', 'bar 14', 'wine', 304.05416238261387),
#  ('person 51', 'bar 18', 'vodka', 79.2083988361992),
#  ('person 52', 'bar 18', 'soda', 3.477885484928265),
#  ('person 52', 'bar 18', 'vodka', 79.2083988361992),
#  ('person 52', 'bar 18', 'wine', 232.95805541472507),
#  ('person 52', 'bar 7', 'soda', 7.467219435609877),
#  ('person 52', 'bar 7', 'vodka', 47.559167791623615),
#  ('person 52', 'bar 7', 'whisky', 91.36447654338554),
#  ('person 52', 'bar 8', 'whisky', 20.28641964425333),
#  ('person 52', 'bar 8', 'wine', 263.50760182598606),
#  ('person 53', 'bar 10', 'beer', 8.69366755662486),
#  ('person 53', 'bar 10', 'vodka', 41.91033443668857),
#  ('person 53', 'bar 10', 'wine', 206.86078639794144),
#  ('person 53', 'bar 16', 'soda', 8.259685171069577),
#  ('person 53', 'bar 16', 'wine', 478.06815632339567),
#  ('person 53', 'bar 18', 'soda', 3.477885484928265),
#  ('person 53', 'bar 18', 'vodka', 79.2083988361992),
#  ('person 53', 'bar 19', 'cocktail', 11.775652277283372),
#  ('person 53', 'bar 19', 'whisky', 34.50718138250522),
#  ('person 53', 'bar 3', 'beer', 4.634161106310785),
#  ('person 53', 'bar 3', 'soda', 7.087707950500771),
#  ('person 53', 'bar 3', 'whisky', 52.187310544541106),
#  ('person 53', 'bar 4', 'vodka', 34.62181418668479),
#  ('person 53', 'bar 4', 'vodka', 93.54708173545077),
#  ('person 53', 'bar 4', 'whisky', 65.86470233043656),
#  ('person 53', 'bar 5', 'beer', 8.457143946550786),
#  ('person 53', 'bar 5', 'wine', 468.4320961767807),
#  ('person 53', 'bar 6', 'rum', 15.327792656607926),
#  ('person 53', 'bar 6', 'whisky', 55.271910273004316),
#  ('person 54', 'bar 1', 'cocktail', 17.112810402177274),
#  ('person 54', 'bar 1', 'whisky', 60.820202879840515),
#  ('person 54', 'bar 1', 'wine', 313.7675603996031),
#  ('person 54', 'bar 10', 'beer', 8.69366755662486),
#  ('person 54', 'bar 10', 'vodka', 41.91033443668857),
#  ('person 54', 'bar 10', 'wine', 206.86078639794144),
#  ('person 54', 'bar 12', 'cocktail', 26.84480233117938),
#  ('person 54', 'bar 12', 'whisky', 50.32640918623656),
#  ('person 54', 'bar 12', 'wine', 443.17386074643576),
#  ('person 54', 'bar 19', 'cocktail', 11.775652277283372),
#  ('person 54', 'bar 19', 'rum', 18.195812245830894),
#  ('person 54', 'bar 3', 'soda', 7.087707950500771),
#  ('person 54', 'bar 4', 'vodka', 34.62181418668479),
#  ('person 54', 'bar 4', 'whisky', 65.86470233043656),
#  ('person 55', 'bar 13', 'cocktail', 26.30280829500407),
#  ('person 55', 'bar 13', 'wine', 289.89556255424395),
#  ('person 55', 'bar 13', 'wine', 411.3109796284698),
#  ('person 55', 'bar 15', 'whisky', 53.23563067126088),
#  ('person 56', 'bar 10', 'vodka', 41.91033443668857),
#  ('person 56', 'bar 11', 'cocktail', 22.64080404303968),
#  ('person 56', 'bar 11', 'whisky', 46.720566569129),
#  ('person 56', 'bar 14', 'wine', 304.05416238261387),
#  ('person 56', 'bar 15', 'whisky', 53.23563067126088),
#  ('person 56', 'bar 15', 'wine', 144.248119993601),
#  ('person 56', 'bar 19', 'cocktail', 11.775652277283372),
#  ('person 56', 'bar 19', 'rum', 18.195812245830894),
#  ('person 56', 'bar 19', 'whisky', 34.50718138250522),
#  ('person 56', 'bar 2', 'beer', 7.54580516833812),
#  ('person 56', 'bar 20', 'beer', 7.961273210588843),
#  ('person 56', 'bar 20', 'rum', 9.153013579780236),
#  ('person 56', 'bar 3', 'beer', 4.634161106310785),
#  ('person 56', 'bar 3', 'soda', 7.087707950500771),
#  ('person 56', 'bar 3', 'whisky', 52.187310544541106),
#  ('person 56', 'bar 5', 'beer', 8.457143946550786),
#  ('person 56', 'bar 5', 'wine', 468.4320961767807),
#  ('person 56', 'bar 6', 'cocktail', 12.44799837935716),
#  ('person 56', 'bar 6', 'rum', 15.327792656607926),
#  ('person 57', 'bar 10', 'wine', 206.86078639794144),
#  ('person 57', 'bar 11', 'beer', 6.242309574503452),
#  ('person 57', 'bar 11', 'cocktail', 22.64080404303968),
#  ('person 57', 'bar 11', 'whisky', 46.720566569129),
#  ('person 57', 'bar 12', 'cocktail', 26.84480233117938),
#  ('person 57', 'bar 12', 'whisky', 50.32640918623656),
#  ('person 57', 'bar 12', 'wine', 443.17386074643576),
#  ('person 57', 'bar 13', 'cocktail', 26.30280829500407),
#  ('person 57', 'bar 13', 'wine', 289.89556255424395),
#  ('person 57', 'bar 13', 'wine', 411.3109796284698),
#  ('person 57', 'bar 14', 'vodka', 57.02846114523709),
#  ('person 57', 'bar 14', 'wine', 6.28380866907537),
#  ('person 57', 'bar 14', 'wine', 304.05416238261387),
#  ('person 57', 'bar 15', 'cocktail', 25.87160057388246),
#  ('person 57', 'bar 15', 'whisky', 53.23563067126088),
#  ('person 57', 'bar 15', 'wine', 144.248119993601),
#  ('person 57', 'bar 16', 'cocktail', 27.076269071549177),
#  ('person 57', 'bar 16', 'soda', 8.259685171069577),
#  ('person 57', 'bar 16', 'wine', 478.06815632339567),
#  ('person 57', 'bar 20', 'beer', 6.543673591222614),
#  ('person 57', 'bar 20', 'rum', 9.153013579780236),
#  ('person 57', 'bar 3', 'beer', 4.634161106310785),
#  ('person 57', 'bar 3', 'soda', 7.087707950500771),
#  ('person 57', 'bar 4', 'vodka', 93.54708173545077),
#  ('person 57', 'bar 5', 'wine', 468.4320961767807),
#  ('person 57', 'bar 7', 'soda', 7.467219435609877),
#  ('person 57', 'bar 7', 'vodka', 47.559167791623615),
#  ('person 57', 'bar 7', 'whisky', 91.36447654338554),
#  ('person 58', 'bar 1', 'cocktail', 17.112810402177274),
#  ('person 58', 'bar 1', 'whisky', 60.820202879840515),
#  ('person 58', 'bar 10', 'beer', 8.69366755662486),
#  ('person 58', 'bar 10', 'vodka', 41.91033443668857),
#  ('person 58', 'bar 16', 'cocktail', 27.076269071549177),
#  ('person 58', 'bar 16', 'soda', 8.259685171069577),
#  ('person 58', 'bar 16', 'wine', 478.06815632339567),
#  ('person 58', 'bar 4', 'vodka', 34.62181418668479),
#  ('person 58', 'bar 4', 'vodka', 93.54708173545077),
#  ('person 58', 'bar 4', 'whisky', 65.86470233043656),
#  ('person 58', 'bar 7', 'soda', 7.467219435609877),
#  ('person 58', 'bar 8', 'whisky', 20.28641964425333),
#  ('person 58', 'bar 8', 'wine', 263.50760182598606),
#  ('person 59', 'bar 1', 'cocktail', 17.112810402177274),
#  ('person 59', 'bar 1', 'whisky', 60.820202879840515),
#  ('person 59', 'bar 1', 'wine', 313.7675603996031),
#  ('person 59', 'bar 16', 'cocktail', 27.076269071549177),
#  ('person 59', 'bar 16', 'soda', 8.259685171069577),
#  ('person 59', 'bar 16', 'wine', 478.06815632339567),
#  ('person 59', 'bar 19', 'rum', 18.195812245830894),
#  ('person 59', 'bar 19', 'whisky', 34.50718138250522),
#  ('person 59', 'bar 20', 'beer', 6.543673591222614),
#  ('person 59', 'bar 20', 'beer', 7.961273210588843),
#  ('person 59', 'bar 5', 'soda', 7.172601338941604),
#  ('person 59', 'bar 9', 'cocktail', 26.487211599014696),
#  ('person 59', 'bar 9', 'vodka', 99.06146339606494),
#  ('person 6', 'bar 11', 'beer', 6.242309574503452),
#  ('person 6', 'bar 11', 'cocktail', 22.64080404303968),
#  ('person 6', 'bar 11', 'whisky', 46.720566569129),
#  ('person 6', 'bar 18', 'soda', 3.477885484928265),
#  ('person 6', 'bar 18', 'vodka', 79.2083988361992),
#  ('person 6', 'bar 18', 'wine', 232.95805541472507),
#  ('person 6', 'bar 20', 'beer', 6.543673591222614),
#  ('person 6', 'bar 20', 'beer', 7.961273210588843),
#  ('person 6', 'bar 5', 'beer', 8.457143946550786),
#  ('person 6', 'bar 5', 'soda', 7.172601338941604),
#  ('person 6', 'bar 5', 'wine', 468.4320961767807),
#  ('person 6', 'bar 6', 'rum', 15.327792656607926),
#  ('person 6', 'bar 6', 'whisky', 55.271910273004316),
#  ('person 60', 'bar 18', 'soda', 3.477885484928265),
#  ('person 60', 'bar 19', 'cocktail', 11.775652277283372),
#  ('person 60', 'bar 3', 'beer', 4.634161106310785),
#  ('person 60', 'bar 3', 'soda', 7.087707950500771),
#  ('person 60', 'bar 6', 'rum', 15.327792656607926),
#  ('person 60', 'bar 6', 'whisky', 55.271910273004316),
#  ('person 60', 'bar 7', 'soda', 7.467219435609877),
#  ('person 60', 'bar 7', 'vodka', 47.559167791623615),
#  ('person 60', 'bar 7', 'whisky', 91.36447654338554),
#  ('person 61', 'bar 11', 'beer', 6.242309574503452),
#  ('person 61', 'bar 11', 'cocktail', 22.64080404303968),
#  ('person 61', 'bar 11', 'whisky', 46.720566569129),
#  ('person 61', 'bar 20', 'beer', 7.961273210588843),
#  ('person 61', 'bar 20', 'rum', 9.153013579780236),
#  ('person 62', 'bar 1', 'whisky', 60.820202879840515),
#  ('person 62', 'bar 1', 'wine', 313.7675603996031),
#  ('person 62', 'bar 11', 'beer', 6.242309574503452),
#  ('person 62', 'bar 12', 'cocktail', 26.84480233117938),
#  ('person 62', 'bar 12', 'whisky', 50.32640918623656),
#  ('person 62', 'bar 12', 'wine', 443.17386074643576),
#  ('person 62', 'bar 14', 'wine', 6.28380866907537),
#  ('person 62', 'bar 14', 'wine', 304.05416238261387),
#  ('person 62', 'bar 18', 'soda', 3.477885484928265),
#  ('person 62', 'bar 18', 'vodka', 79.2083988361992),
#  ('person 62', 'bar 18', 'wine', 232.95805541472507),
#  ('person 62', 'bar 19', 'cocktail', 11.775652277283372),
#  ('person 62', 'bar 19', 'whisky', 34.50718138250522),
#  ('person 62', 'bar 20', 'beer', 7.961273210588843),
#  ('person 62', 'bar 4', 'vodka', 34.62181418668479),
#  ('person 62', 'bar 4', 'vodka', 93.54708173545077),
#  ('person 62', 'bar 5', 'beer', 8.457143946550786),
#  ('person 62', 'bar 5', 'soda', 7.172601338941604),
#  ('person 62', 'bar 5', 'wine', 468.4320961767807),
#  ('person 63', 'bar 11', 'beer', 6.242309574503452),
#  ('person 63', 'bar 11', 'cocktail', 22.64080404303968),
#  ('person 63', 'bar 11', 'whisky', 46.720566569129),
#  ('person 63', 'bar 4', 'vodka', 34.62181418668479),
#  ('person 63', 'bar 4', 'vodka', 93.54708173545077),
#  ('person 63', 'bar 5', 'wine', 468.4320961767807),
#  ('person 63', 'bar 8', 'whisky', 20.28641964425333),
#  ('person 63', 'bar 8', 'wine', 263.50760182598606),
#  ('person 64', 'bar 1', 'whisky', 60.820202879840515),
#  ('person 64', 'bar 1', 'wine', 313.7675603996031),
#  ('person 64', 'bar 12', 'cocktail', 26.84480233117938),
#  ('person 64', 'bar 12', 'whisky', 50.32640918623656),
#  ('person 64', 'bar 12', 'wine', 443.17386074643576),
#  ('person 64', 'bar 14', 'wine', 6.28380866907537),
#  ('person 64', 'bar 14', 'wine', 304.05416238261387),
#  ('person 64', 'bar 16', 'cocktail', 27.076269071549177),
#  ('person 64', 'bar 16', 'wine', 478.06815632339567),
#  ('person 64', 'bar 19', 'cocktail', 11.775652277283372),
#  ('person 64', 'bar 19', 'rum', 18.195812245830894),
#  ('person 64', 'bar 19', 'whisky', 34.50718138250522),
#  ('person 64', 'bar 3', 'beer', 4.634161106310785),
#  ('person 64', 'bar 3', 'soda', 7.087707950500771),
#  ('person 64', 'bar 3', 'whisky', 52.187310544541106),
#  ('person 64', 'bar 7', 'soda', 7.467219435609877),
#  ('person 64', 'bar 7', 'whisky', 91.36447654338554),
#  ('person 65', 'bar 13', 'cocktail', 26.30280829500407),
#  ('person 65', 'bar 13', 'wine', 411.3109796284698),
#  ('person 65', 'bar 14', 'vodka', 57.02846114523709),
#  ('person 65', 'bar 14', 'wine', 304.05416238261387),
#  ('person 65', 'bar 15', 'cocktail', 25.87160057388246),
#  ('person 65', 'bar 15', 'whisky', 53.23563067126088),
#  ('person 65', 'bar 15', 'wine', 144.248119993601),
#  ('person 65', 'bar 18', 'vodka', 79.2083988361992),
#  ('person 65', 'bar 20', 'beer', 6.543673591222614),
#  ('person 65', 'bar 20', 'beer', 7.961273210588843),
#  ('person 65', 'bar 5', 'beer', 8.457143946550786),
#  ('person 65', 'bar 5', 'soda', 7.172601338941604),
#  ('person 65', 'bar 5', 'wine', 468.4320961767807),
#  ('person 65', 'bar 8', 'whisky', 20.28641964425333),
#  ('person 65', 'bar 8', 'whisky', 45.60507479473017),
#  ('person 66', 'bar 1', 'cocktail', 17.112810402177274),
#  ('person 66', 'bar 1', 'wine', 313.7675603996031),
#  ('person 66', 'bar 12', 'cocktail', 26.84480233117938),
#  ('person 66', 'bar 12', 'whisky', 50.32640918623656),
#  ('person 66', 'bar 12', 'wine', 443.17386074643576),
#  ('person 66', 'bar 15', 'cocktail', 25.87160057388246),
#  ('person 66', 'bar 15', 'whisky', 53.23563067126088),
#  ('person 66', 'bar 15', 'wine', 144.248119993601),
#  ('person 66', 'bar 16', 'cocktail', 27.076269071549177),
#  ('person 66', 'bar 16', 'soda', 8.259685171069577),
#  ('person 66', 'bar 16', 'wine', 478.06815632339567),
#  ('person 66', 'bar 18', 'soda', 3.477885484928265),
#  ('person 66', 'bar 20', 'beer', 6.543673591222614),
#  ('person 66', 'bar 20', 'beer', 7.961273210588843),
#  ('person 66', 'bar 20', 'rum', 9.153013579780236),
#  ('person 66', 'bar 4', 'vodka', 34.62181418668479),
#  ('person 66', 'bar 4', 'whisky', 65.86470233043656),
#  ('person 66', 'bar 7', 'soda', 7.467219435609877),
#  ('person 66', 'bar 7', 'whisky', 91.36447654338554),
#  ('person 66', 'bar 9', 'whisky', 74.95702381711453),
#  ('person 67', 'bar 1', 'cocktail', 17.112810402177274),
#  ('person 67', 'bar 1', 'whisky', 60.820202879840515),
#  ('person 67', 'bar 1', 'wine', 313.7675603996031),
#  ('person 67', 'bar 10', 'beer', 8.69366755662486),
#  ('person 67', 'bar 10', 'vodka', 41.91033443668857),
#  ('person 67', 'bar 10', 'wine', 206.86078639794144),
#  ('person 67', 'bar 11', 'beer', 6.242309574503452),
#  ('person 67', 'bar 11', 'cocktail', 22.64080404303968),
#  ('person 67', 'bar 11', 'whisky', 46.720566569129),
#  ('person 67', 'bar 19', 'cocktail', 11.775652277283372),
#  ('person 67', 'bar 19', 'rum', 18.195812245830894),
#  ('person 67', 'bar 19', 'whisky', 34.50718138250522),
#  ('person 67', 'bar 6', 'rum', 15.327792656607926),
#  ('person 67', 'bar 6', 'whisky', 55.271910273004316),
#  ('person 68', 'bar 11', 'cocktail', 22.64080404303968),
#  ('person 68', 'bar 14', 'vodka', 57.02846114523709),
#  ('person 68', 'bar 14', 'wine', 6.28380866907537),
#  ('person 68', 'bar 14', 'wine', 304.05416238261387),
#  ('person 68', 'bar 4', 'vodka', 34.62181418668479),
#  ('person 68', 'bar 4', 'whisky', 65.86470233043656),
#  ('person 69', 'bar 1', 'cocktail', 17.112810402177274),
#  ('person 69', 'bar 1', 'wine', 313.7675603996031),
#  ('person 69', 'bar 17', 'whisky', 23.555515306070447),
#  ('person 69', 'bar 17', 'wine', 302.8571365196258),
#  ('person 69', 'bar 20', 'beer', 7.961273210588843),
#  ('person 69', 'bar 6', 'whisky', 55.271910273004316),
#  ('person 69', 'bar 8', 'whisky', 20.28641964425333),
#  ('person 69', 'bar 8', 'whisky', 45.60507479473017),
#  ('person 69', 'bar 8', 'wine', 263.50760182598606),
#  ('person 7', 'bar 1', 'cocktail', 17.112810402177274),
#  ('person 7', 'bar 1', 'whisky', 60.820202879840515),
#  ('person 7', 'bar 1', 'wine', 313.7675603996031),
#  ('person 7', 'bar 14', 'wine', 6.28380866907537),
#  ('person 7', 'bar 14', 'wine', 304.05416238261387),
#  ('person 7', 'bar 3', 'beer', 4.634161106310785),
#  ('person 7', 'bar 3', 'soda', 7.087707950500771),
#  ('person 7', 'bar 3', 'whisky', 52.187310544541106),
#  ('person 7', 'bar 7', 'soda', 7.467219435609877),
#  ('person 7', 'bar 7', 'vodka', 47.559167791623615),
#  ...]

# %% [markdown]
# ---
# ## Below are my answers

# %% [markdown]
# ### Answer 1

# %%
# %%sql sqlite://
# SELECT bar, AVG(price) AS avg_price
# FROM menu_items
# GROUP BY bar;
# Out:
# (sqlite3.OperationalError) no such table: menu_items
# [SQL: SELECT bar, AVG(price) AS avg_price
# FROM menu_items
# GROUP BY bar;]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %% [markdown]
# >When you use an aggregate function, should use a `GROUP BY` (or it will aggregate the entire column).
#
# >Whenever you use a `GROUP BY`, your selected columns need an aggregation (unless it's the `GROUP BY` column)
# (i.e. `SELECT drink_id` gives error)

# %% [markdown]
# ### Answer 2

# %%
# %%sql sqlite://
# SELECT bar, AVG(price) AS avg_price
# FROM menu_items
# GROUP BY bar
# ORDER BY avg_price DESC
# LIMIT 5;
# Out:
# (sqlite3.OperationalError) no such table: menu_items
# [SQL: SELECT bar, AVG(price) AS avg_price
# FROM menu_items
# GROUP BY bar
# ORDER BY avg_price DESC
# LIMIT 5;]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %% [markdown]
# > Can also use `ORDER BY 2 DESC`

# %% [markdown]
# ### Answer 3

# %%
# %%sql sqlite://
# SELECT menu_items.bar, drinks.type, menu_items.price
# FROM menu_items JOIN drinks ON menu_items.drink_id=drinks.drink_id
# ORDER BY price ASC
# LIMIT 1;

# %% [markdown]
# > Since we also need the drink type and price, we cannot use `MIN`

# %% [markdown]
# ### Answer 4

# %%
# %%sql sqlite://
# SELECT orders.bar, SUM(orders.quantity) AS beers_sold
# FROM orders JOIN drinks ON drinks.drink_id = orders.drink_id
# WHERE drinks.type = 'beer'
# GROUP BY orders.bar
# ORDER BY beers_sold DESC;

# %% [markdown]
# > Can also use: `WHERE drinks.type LIKE '%beer%'`

# %% [markdown]
# ### Answer 5

# %%
# %%sql sqlite://
# SELECT o.person, o.bar, d.type, d.drink_id, m.price
# FROM orders AS o
# JOIN menu_items AS m ON (o.drink_id = m.drink_id AND o.bar = m.bar)
# JOIN drinks AS d ON o.drink_id = d.drink_id
# GROUP BY o.person, o.bar, d.type, d.drink_id, m.price;
