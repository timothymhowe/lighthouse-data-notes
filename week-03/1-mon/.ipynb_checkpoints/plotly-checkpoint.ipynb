# %%
# import sys
# !conda remove --yes --prefix {sys.prefix} dash

# !conda install  --yes --prefix {sys.prefix} -c conda-forge dash-renderer
# # !conda install  --yes --prefix {sys.prefix} -c conda-forge dash 
# !conda install  --yes --prefix {sys.prefix} -c conda-forge dash-html-components 
# !conda install --yes --prefix {sys.prefix} -c conda-forge dash-core-components
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/thowe/anaconda3/envs/LighthouseEnv
#
#   removed specs:
#     - dash
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     abseil-cpp-20211102.0      |       hd4dd3e8_0        1020 KB
#     aws-c-common-0.6.2         |       h27cfd23_0         164 KB
#     bottleneck-1.3.5           |  py310ha9d4c09_0         274 KB
#     debugpy-1.5.1              |  py310h295c915_0         1.7 MB
#     entrypoints-0.4            |  py310h06a4308_0          16 KB
#     ipython-8.3.0              |  py310h06a4308_0         977 KB
#     jedi-0.18.1                |  py310h06a4308_1         988 KB
#     jupyter_client-7.2.2       |  py310h06a4308_0         193 KB
#     jupyter_core-4.10.0        |  py310h06a4308_0          76 KB
#     libgfortran-ng-11.2.0      |       h00389a5_1          20 KB
# ...

# %%
import plotly

# %%
import dash
